# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotigiri7219/Practice/blob/main/MergingJoiningConcatination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
student =pd.DataFrame({
    'SUB':['MATHS','ENGLISH','HINDI','SCI'],
    'SURESH':[52,78,75,58],
    'ROHAN':[55,55,45,88],
    'SHREYASH':[75,57,65,45]
})
student

teacher = pd.DataFrame({

})
# Out:
#        SUB  SURESH  ROHAN  SHREYASH
# 0    MATHS      52     55        75
# 1  ENGLISH      78     55        57
# 2    HINDI      75     45        65
# 3      SCI      58     88        45
