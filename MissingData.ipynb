# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotigiri7219/Practice/blob/main/MissingData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Finding Miaaing Data**

# %%
data = {
    'A':[1,2,np.nan,4,5],
    'B':[np.nan,np.nan,np.nan,4,np.nan],
    'C':[1,2,3,np.nan,5],
    'D':[6,7,np.nan,9,10],
    'E':[11,12,13,14,15]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B    C     D   E
# 0  1.0  NaN  1.0   6.0  11
# 1  2.0  NaN  2.0   7.0  12
# 2  NaN  NaN  3.0   NaN  13
# 3  4.0  4.0  NaN   9.0  14
# 4  5.0  NaN  5.0  10.0  15

# %%
df.isna()
# Out:
#        A      B      C      D      E
# 0  False   True  False  False  False
# 1  False   True  False  False  False
# 2   True   True  False   True  False
# 3  False  False   True  False  False
# 4  False   True  False  False  False

# %%
df.isna().sum() # row nan value finde
# Out:
# A    1
# B    4
# C    1
# D    1
# E    0
# dtype: int64

# %%
df.isna().any() # column nan value find
# Out:
# A     True
# B     True
# C     True
# D     True
# E    False
# dtype: bool

# %%
df
# Out:
#      A    B    C     D   E
# 0  1.0  NaN  1.0   6.0  11
# 1  2.0  NaN  2.0   7.0  12
# 2  NaN  NaN  3.0   NaN  13
# 3  4.0  4.0  NaN   9.0  14
# 4  5.0  NaN  5.0  10.0  15

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E]
# Index: []

# %%
df.dropna(thresh=4)
# Out:
#      A    B    C     D   E
# 0  1.0  NaN  1.0   6.0  11
# 1  2.0  NaN  2.0   7.0  12
# 3  4.0  4.0  NaN   9.0  14
# 4  5.0  NaN  5.0  10.0  15

# %% [markdown]
# **Filling the missing data**

# %%
df
# Out:
#      A    B    C     D   E
# 0  1.0  NaN  1.0   6.0  11
# 1  2.0  NaN  2.0   7.0  12
# 2  NaN  NaN  3.0   NaN  13
# 3  4.0  4.0  NaN   9.0  14
# 4  5.0  NaN  5.0  10.0  15

# %%
df.fillna(0)
# Out:
#      A    B    C     D   E
# 0  1.0  0.0  1.0   6.0  11
# 1  2.0  0.0  2.0   7.0  12
# 2  0.0  0.0  3.0   0.0  13
# 3  4.0  4.0  0.0   9.0  14
# 4  5.0  0.0  5.0  10.0  15

# %%
values = { 'A':200,'B':300,'C':400,'D':600,'E':900}
df.fillna(value=values)
# Out:
#        A      B      C      D   E
# 0    1.0  300.0    1.0    6.0  11
# 1    2.0  300.0    2.0    7.0  12
# 2  200.0  300.0    3.0  600.0  13
# 3    4.0    4.0  400.0    9.0  14
# 4    5.0  300.0    5.0   10.0  15

# %%
df
# Out:
#      A    B    C     D   E
# 0  1.0  NaN  1.0   6.0  11
# 1  2.0  NaN  2.0   7.0  12
# 2  NaN  NaN  3.0   NaN  13
# 3  4.0  4.0  NaN   9.0  14
# 4  5.0  NaN  5.0  10.0  15

# %%
df.fillna(df.mean())
# Out:
#      A    B     C     D   E
# 0  1.0  4.0  1.00   6.0  11
# 1  2.0  4.0  2.00   7.0  12
# 2  3.0  4.0  3.00   8.0  13
# 3  4.0  4.0  2.75   9.0  14
# 4  5.0  4.0  5.00  10.0  15
