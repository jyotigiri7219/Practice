# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotigiri7219/Practice/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
labels = ['A','B','C']
l = [10,20,30]
arr = np.array([10,20,30])
d = {1:10,2:20,3:30}

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %% [markdown]
# **Series**

# %%
pd.Series(data=arr,index=labels)
# Out:
# A    10
# B    20
# C    30
# dtype: int64

# %% [markdown]
# **DataFrame**

# %%
data = {
    "Name":["Ayush","Jyoti","Adarsh","Roshni"],
    "Age":[8,20,14,17],
    "City":["Virar","Andheri","Mira road","nallsopra"],
    "Saleary":[20000,25000,30000,50000]
}

# %%
pd.DataFrame(data)
# Out:
#      Name  Age       City  Saleary
# 0   Ayush    8      Virar    20000
# 1   Jyoti   20    Andheri    25000
# 2  Adarsh   14  Mira road    30000
# 3  Roshni   17  nallsopra    50000

# %% [markdown]
# **Create use data in the list **

# %%
data_list = [
    ["Ayush","Jyoti","Adarsh","Roshni"],
    [8,20,14,17],
    ["Virar","Andheri","Mira road","nallsopra"],
    [20000,25000,30000,50000]
    ]
df2 = pd.DataFrame(data_list)

# %%
df2 = pd.DataFrame(data_list)
df2
# Out:
#        0        1          2          3
# 0  Ayush    Jyoti     Adarsh     Roshni
# 1      8       20         14         17
# 2  Virar  Andheri  Mira road  nallsopra
# 3  20000    25000      30000      50000

# %%
df2
# Out:
#        0        1          2          3
# 0  Ayush    Jyoti     Adarsh     Roshni
# 1      8       20         14         17
# 2  Virar  Andheri  Mira road  nallsopra
# 3  20000    25000      30000      50000

# %%
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns=columns)
df2
# Out:
#     Name      Age       City     Salary
# 0  Ayush    Jyoti     Adarsh     Roshni
# 1      8       20         14         17
# 2  Virar  Andheri  Mira road  nallsopra
# 3  20000    25000      30000      50000

# %%
df2
# Out:
#     Name      Age       City     Salary
# 0  Ayush    Jyoti     Adarsh     Roshni
# 1      8       20         14         17
# 2  Virar  Andheri  Mira road  nallsopra
# 3  20000    25000      30000      50000

# %% [markdown]
# **select index and columns**

# %%
df2
# Out:
#     Name      Age       City     Salary
# 0  Ayush    Jyoti     Adarsh     Roshni
# 1      8       20         14         17
# 2  Virar  Andheri  Mira road  nallsopra
# 3  20000    25000      30000      50000

# %%
df2[["Name","City"]]
# Out:
#     Name       City
# 0  Ayush     Adarsh
# 1      8         14
# 2  Virar  Mira road
# 3  20000      30000

# %% [markdown]
# **New column cri**

# %%
df2["DPT"] = ["doctor","engineer","doctor","Engineerr"]

# %%
df2
# Out:
#     Name      Age       City     Salary        DPT
# 0  Ayush    Jyoti     Adarsh     Roshni     doctor
# 1      8       20         14         17   engineer
# 2  Virar  Andheri  Mira road  nallsopra     doctor
# 3  20000    25000      30000      50000  Engineerr

# %% [markdown]
# **Remove column**

# %%
df2.drop("DPT", axis =  1)
# Out:
#     Name      Age       City     Salary
# 0  Ayush    Jyoti     Adarsh     Roshni
# 1      8       20         14         17
# 2  Virar  Andheri  Mira road  nallsopra
# 3  20000    25000      30000      50000

# %%
df2
# Out:
#     Name      Age       City     Salary        DPT
# 0  Ayush    Jyoti     Adarsh     Roshni     doctor
# 1      8       20         14         17   engineer
# 2  Virar  Andheri  Mira road  nallsopra     doctor
# 3  20000    25000      30000      50000  Engineerr

# %%
df2.drop("DPT", axis = 1, inplace = True, errors='ignore')
df2
# Out:
#     Name      Age       City     Salary
# 0  Ayush    Jyoti     Adarsh     Roshni
# 1      8       20         14         17
# 2  Virar  Andheri  Mira road  nallsopra
# 3  20000    25000      30000      50000

# %%
df2.drop(["Name","City"], axis = 1)
# Out:
#        Age     Salary
# 0    Jyoti     Roshni
# 1       20         17
# 2  Andheri  nallsopra
# 3    25000      50000

# %%
df2
# Out:
#     Name      Age       City     Salary
# 0  Ayush    Jyoti     Adarsh     Roshni
# 1      8       20         14         17
# 2  Virar  Andheri  Mira road  nallsopra
# 3  20000    25000      30000      50000

# %% [markdown]
# **Selecting rows**

# %%
df2
# Out:
#     Name      Age       City     Salary
# 0  Ayush    Jyoti     Adarsh     Roshni
# 1      8       20         14         17
# 2  Virar  Andheri  Mira road  nallsopra
# 3  20000    25000      30000      50000

# %%
df2.loc[0]
# Out:
# Name       Ayush
# Age        Jyoti
# City      Adarsh
# Salary    Roshni
# Name: 0, dtype: object

# %%
df2.iloc[3]
# Out:
# Name      20000
# Age       25000
# City      30000
# Salary    50000
# Name: 3, dtype: object
